# %%
import numpy as np
import astropy.constants as const
import astropy.units as units
import bokeh.plotting as blt
import bokeh
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="87d5c027-6d01-40e5-a2da-35628e79db03">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # q3

# %%
#units are solar masses, kpc and Gyr
G=const.G.to((units.kpc**3)/(const.M_sun*(units.Gyr**2))).value
def vCirc(rad,Ma,a):
    return np.sqrt(G*rMass(rad,Ma,a)/rad)
def rMass(rad,Ma,a): #mass within radius r
    return Ma*( np.log(1+(rad/a)) - (rad/(a+rad)) )
def phi(rad,Ma,a):
    return -G*Ma*np.log(1+(rad/a))/rad
def effPhi(rad,Ma,a,l):
    return phi(rad,Ma,a) + ((l**2)/(2*(rad**2)))
def energy(rad,rDot,Ma,a,l):
    return (rDot**2)/2 + effPhi(rad,Ma,a,l)
def eCirc(rad,Ma,a,l): #energy assuming a circular orbit
    return (vCirc(rad,Ma,a)**2)/2 + phi(rad,Ma,a)
def lMax(rad,Ma,a,E):
    return rad*np.sqrt(2*(E-phi(rad,Ma,a)))

# %% [markdown]
# # 3.a

# %%
Ma=1e11
a=2
testR=np.linspace(0.1,25,100)
plotW=400
plotH=200
vCircPlot=blt.figure(width=plotW,height=plotH,
                     x_axis_label='r (kpc)',y_axis_label='v_c (kpc/Gyr)',
                     y_axis_type="log")
vCircPlot.line(testR,vCirc(testR,Ma,a),line_width=2)
mPlot=blt.figure(width=plotW,height=plotH,
                 x_axis_label='r (kpc)',y_axis_label='M_r (Msun)',
                 y_axis_type="log")
mPlot.line(testR,rMass(testR,Ma,a),line_width=2)
grid=bokeh.layouts.gridplot([[vCircPlot,mPlot]])
blt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d41a11d8-60d6-4e51-b23b-d52a837f3f43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d41a11d8-60d6-4e51-b23b-d52a837f3f43").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d41a11d8-60d6-4e51-b23b-d52a837f3f43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd41a11d8-60d6-4e51-b23b-d52a837f3f43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2e6f385d-7637-4798-99a9-830dc8fcdfb4":{"roots":{"references":[{"attributes":{},"id":"608151db-70cb-4715-9f2b-e470a23d14f4","type":"BasicTicker"},{"attributes":{"ticker":null},"id":"f8393b9c-32f8-4b63-9951-95eb4cee3244","type":"LogTickFormatter"},{"attributes":{"data_source":{"id":"10d2472f-18ac-46a8-bbb0-492f9eda9c6b","type":"ColumnDataSource"},"glyph":{"id":"ecbdba88-c34b-470e-8d91-909845eaa7d5","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9b8e277b-ff31-4b4a-aaaa-1556cd9203b2","type":"Line"},"selection_glyph":null},"id":"84664961-ef1d-420f-af7c-cb9ba4f16cc0","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"764fb9c0-ec7c-4316-bd56-9a0991bbbb88","subtype":"Figure","type":"Plot"},"ticker":{"id":"25c5e414-c926-4dc4-9726-27a1de4bd352","type":"LogTicker"}},"id":"dcf7e766-5094-4d28-828a-c85c4916a4ee","type":"Grid"},{"attributes":{"callback":null},"id":"e8b9a611-3779-436c-93a1-3468b128b250","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"
lot=blt.figure(width=plotW,height=2*plotH,
                 x_axis_label='r (kpc)',y_axis_label='energy',
                 y_range=(-1e5,1e5),x_range=(0,25))
effPhiPlot.line(testR,effPhi(testR,Ma,a,l),line_width=2,legend='effective potential')
effPhiPlot.line(testR,eCirc(testR,Ma,a,l),line_width=2,color='green',legend='energy of circular orbit')
#effPhiPlot.ray(x=[0], y=[0], length=0, angle=0, line_width=2)
#effPhiPlot.ray(x=[0], y=[energy(np.zeros_like(testR),testR,Ma,a,l)]
#               ,length=0, angle=np.pi/2, line_width=2)
blt.show(effPhiPlot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="77b96622-56cb-4a91-9a6a-1bf0d75d59b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("77b96622-56cb-4a91-9a6a-1bf0d75d59b5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77b96622-56cb-4a91-9a6a-1bf0d75d59b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77b96622-56cb-4a91-9a6a-1bf0d75d59b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"12c4fb22-1a92-468e-8cf8-c6bfc674a5ed":{"roots":{"references":[{"attributes":{"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"}},"id":"dd065da6-b2f5-45e0-b4ee-82f26ee34808","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"6ef2e72f-ca78-4a79-92cd-9cac75564122","type":"Title"},{"attributes":{"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"}},"id":"10bf86d0-21ef-4b7f-b816-e14bd1577c20","type":"SaveTool"},{"attributes":{"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"},"ticker":{"id":"e61a607a-a942-49f1-afb6-741530a6c29f","type":"BasicTicker"}},"id":"4863b7f1-6cff-49b5-9595-f5c5886d5758","type":"Grid"},{"attributes":{"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"}},"id":"de0eb800-d08a-4136-b088-d04467c8ec3e","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"42af660d-a14b-4d0f-bfaa-1bd024c0644b","type":"Line"},{"attributes":{"callback":null,"end":25},"id":"0c33295a-549d-4038-bdc4-51c070c6ee4f","type":"Range1d"},{"attributes":{},"id":"1e638a96-c3a0-437a-9d0d-1f00e8152123","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":100000.0,"start":-100000.0},"id":"c149518e-f226-4e8c-8276-4148c82b05b8","type":"Range1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f68965c-5b1e-4ea3-8b4f-e696a354e1c9","type":"Line"},{"attributes":{},"id":"8c9eb154-2b9b-4a6e-93ad-bbb737062d72","type":"BasicTickFormatter"},{"attributes":{},"id":"e61a607a-a942-49f1-afb6-741530a6c29f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb538346-de9f-44b9-9d1a-5eae7085727a","type":"BasicTicker"}},"id":"3d687d5d-6a00-4e3c-bd35-02655cab06e7","type":"Grid"},{"attributes":{},"id":"cb538346-de9f-44b9-9d1a-5eae7085727a","type":"BasicTicker"},{"attributes":{},"id":"0ff0a42f-337a-4beb-995b-1faee0e96d5e","type":"ToolEvents"},{"attributes":{"plot":{"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"}},"id":"55df49ab-ce32-4780-b135-4fa3fd067f22","type":"HelpTool"},{"attributes":{"below":[{"id":"b081e251-f536-4f09-9a49-c6adb1c1d511","type":"LinearAxis"}],"left":[{"id":"89338426-51f8-45f9-89b0-4f9c9a57c482","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"b081e251-f536-4f09-9a49-c6adb1c1d511","type":"LinearAxis"},{"id":"4863b7f1-6cff-49b5-9595-f5c5886d5758","type":"Grid"},{"id":"89338426-51f8-45f9-89b0-4f9c9a57c482","type":"LinearAxis"},{"id":"3d687d5d-6a00-4e3c-bd35-02655cab06e7","type":"Grid"},{"id":"5a993ed7-cf10-48ee-a3da-6e10bea68640","type":"BoxAnnotation"},{"id":"5ec9d16d-f15e-48d4-95a0-388091e0a5a4","type":"Legend"},{"id":"082348ed-4349-49a6-b2e6-7ff70acbfe93","type":"GlyphRenderer"},{"id":"d056b26e-2cdb-44b7-a5e9-8429a7e2819f","type":"GlyphRenderer"}],"title":{"id":"6ef2e72f-ca78-4a79-92cd-9cac75564122","type":"Title"},"tool_events":{"id":"0ff0a42f-337a-4beb-995b-1faee0e96d5e","type":"ToolEvents"},"toolbar":{"id":"ae488555-a970-4181-84c0-5ca97206311e","type":"Toolbar"},"x_range":{"id":"0c33295a-549d-4038-bdc4-51c070c6ee4f","type":"Range1d"},"y_range":{"id":"c149518e-f226-4e8c-8276-4148c82b05b8","type":"Range1d"}},"id":"cac2541e-43e1-493b-9e6f-b4cb894c9570","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"86855529-74e5-4239-a47b-87123ef8c723","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fdad8bc7-713f-4656-92c2-4edf95d9c106","type":"Line"},{"attributes":{"callback":null ...

# %% [markdown]
# # 3.c

# %%
E=5 # for -ve E there exists a maximum l possible
lMaxPlot=blt.figure(width=plotW,height=2*plotH,
                 x_axis_label='r (kpc)',y_axis_label='l_max',
                 x_range=(0,25))
lMaxPlot.line(testR,lMax(testR,Ma,a,E),line_width=2)
blt.show(lMaxPlot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d90cf0e2-fc3f-438d-9b4d-90961fb113ee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d90cf0e2-fc3f-438d-9b4d-90961fb113ee").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d90cf0e2-fc3f-438d-9b4d-90961fb113ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd90cf0e2-fc3f-438d-9b4d-90961fb113ee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"41f2dd2b-4095-464e-819d-fb783b3c41ad":{"roots":{"references":[{"attributes":{},"id":"6cae2049-1589-4f00-a36b-7564b6ce7824","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"d31bd455-23da-464a-8a9f-f4134107dc21","type":"ColumnDataSource"},"glyph":{"id":"60b76de0-07ce-497f-bc33-cb111b81185d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0ef45659-2b5d-44ac-96b8-24b61992b917","type":"Line"},"selection_glyph":null},"id":"c25fe7fb-de81-456d-8868-422933dc0c7b","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"60b76de0-07ce-497f-bc33-cb111b81185d","type":"Line"},{"attributes":{"plot":{"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"}},"id":"221a62a9-4426-48c1-b7a2-ae00039651f2","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"}},"id":"a2047b36-a57e-4c7b-8832-23897eafb29a","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"0e7c6a1a-d2e0-4456-87a9-a13f99bf107d","type":"Title"},{"attributes":{"axis_label":"r (kpc)","formatter":{"id":"8ccf95ca-ebaf-4ce3-bd24-d1493b8d2e42","type":"BasicTickFormatter"},"plot":{"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"},"ticker":{"id":"c48c6579-103b-4a2f-831c-799393942bf7","type":"BasicTicker"}},"id":"529edbf4-3206-4acc-81b6-b624449922f5","type":"LinearAxis"},{"attributes":{},"id":"e55f59f2-59c5-46b3-92a0-6705e58220cf","type":"ToolEvents"},{"attributes":{},"id":"50e708b6-66ff-4d87-8225-f18a283da65c","type":"BasicTicker"},{"attributes":{"plot":{"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"}},"id":"1eea6d6c-a53b-4bd4-b180-a2b656153f0b","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"078cba42-1d5e-42cb-be0c-dc05ac1846f3","type":"PanTool"},{"id":"221a62a9-4426-48c1-b7a2-ae00039651f2","type":"WheelZoomTool"},{"id":"b9047a92-a2a8-4e6f-9d90-5027fe2755b9","type":"BoxZoomTool"},{"id":"1eea6d6c-a53b-4bd4-b180-a2b656153f0b","type":"SaveTool"},{"id":"a2047b36-a57e-4c7b-8832-23897eafb29a","type":"ResetTool"},{"id":"1d603b3a-f06a-48f5-b3a1-5a3b90d217e7","type":"HelpTool"}]},"id":"7bbefed5-a774-4eee-8727-8e068433aee3","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"},"ticker":{"id":"50e708b6-66ff-4d87-8225-f18a283da65c","type":"BasicTicker"}},"id":"e9db07d6-65f9-49a3-9535-eec8414066ac","type":"Grid"},{"attributes":{"callback":null},"id":"6875502a-3f03-4c87-b018-37452761bca7","type":"DataRange1d"},{"attributes":{"below":[{"id":"529edbf4-3206-4acc-81b6-b624449922f5","type":"LinearAxis"}],"left":[{"id":"b7be2fad-1871-4159-afb7-47bd41a9f666","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"529edbf4-3206-4acc-81b6-b624449922f5","type":"LinearAxis"},{"id":"c72f7bcc-8775-4894-9d57-acd6acfad3cd","type":"Grid"},{"id":"b7be2fad-1871-4159-afb7-47bd41a9f666","type":"LinearAxis"},{"id":"e9db07d6-65f9-49a3-9535-eec8414066ac","type":"Grid"},{"id":"0ce39787-bdd2-46f8-bb1f-cab1600d344f","type":"BoxAnnotation"},{"id":"c25fe7fb-de81-456d-8868-422933dc0c7b","type":"GlyphRenderer"}],"title":{"id":"0e7c6a1a-d2e0-4456-87a9-a13f99bf107d","type":"Title"},"tool_events":{"id":"e55f59f2-59c5-46b3-92a0-6705e58220cf","type":"ToolEvents"},"toolbar":{"id":"7bbefed5-a774-4eee-8727-8e068433aee3","type":"Toolbar"},"x_range":{"id":"3685a3b0-af7a-4bb2-aaa7-06d8bf33e00e","type":"Range1d"},"y_range":{"id":"6875502a-3f03-4c87-b018-37452761bca7","type":"DataRange1d"}},"id":"358f7181-5612-4d58-8f6b-bae6de695778","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":25},"id":"3685a3b0-af7a-4bb2-aaa7-06d8bf33e00e","type":"Range1d"},{"attributes":{"axis_label":"l_max","formatter":{"id":"6cae2049-1589-4f00-a36b-7564b6ce7824","type":"BasicTickFormatter" ...

# %% [markdown]
# # q4

# %%
def timeIntegrand(rad,Ma,a,l,E):
    return 2/(2*(E-phi(rad,Ma,a)) + l**2/rad**2)**0.5
def precessIntegrand(rad,Ma,a,l,E):
    return 2*l/(rad**2 * (2*(E-phi(rad,Ma,a)) + l**2/rad**2)**0.5)
def rootBisection(lowBound,highBound,function,Ma,a,l,E):
    low=lowBound
    mid=0.5*(lowBound+highBound)
    high=highBound
    diff=1e10 #just a large number to get started
    count=0
    while((count<100) & (np.abs(diff/E)>0.001)):
        #print('count: ',count,' diff/E: ',diff/E)
        #print('low: ',low,' high: ',high)
        count+=1
        lowDiff=function(low,Ma,a,l)-E
        highDiff=function(high,Ma,a,l)-E
        diff=function(mid,Ma,a,l)-E
        if (np.sign(lowDiff*diff) == 1): #low and mid point on same side of root
            low=mid
            mid=0.5*(low+high)
        elif (np.sign(highDiff*diff) == 1): # high and mid point on same side of root
            high=mid
            mid=0.5*(low+high)
        #else:
            #print('something went wrong, 0 or 2+ roots in range')
    if (count==100):
        #print('did not converge')
        return -1
    return mid
def trapIntegrate(lowBound,highBound,nStep,function,Ma,a,l,E):
    integral=0
    step=np.linspace(lowBound,highBound,nStep+1)
    dStep=step[1]-step[0]
    for i in range(nStep):
        integral+=dStep*(function(step[i],Ma,a,l,E)+function(step[i+1],Ma,a,l,E))/2
    return integral
def plotImage(imageData,cbarName,cbarLow,cbarHigh):
    cmap = bokeh.models.LinearColorMapper(palette="PuOr11", low=cbarLow, high=cbarHigh)
    cbar = bokeh.models.ColorBar(color_mapper=cmap, border_line_color=None, location=(0,0),title=cbarName)
    plot=blt.figure(width=plotW,height=plotH,
                     y_axis_label='l',x_axis_label='E',
                     y_range=(ls[0],ls[-1]),x_range=(Es[0],Es[-1]))
    plot.add_layout(cbar, 'right')
    plot.image(image=[imageData],y=ls[0],x=Es[0],dh=ls[-1]-ls[0],dw=Es[-1]-Es[0],color_mapper=cmap)
    return plot
nL=128
nE=128
ls=np.linspace(5e2,5e3,nL)
Es=np.linspace(-1e5,1e5,nE)

# %% [markdown]
# # 4.a

# %%
def findTurnRad(l,E):
    minRad=-1
    maxRad=-1
    if(E>0): #only one root
        minRad=rootBisection(1,1e5,effPhi,Ma,a,l,E)
    elif(E<0):
        circRad=rootBisection(1,1e5,eCirc,Ma,a,l,E) #if 2 roots need to find center point to bisect around
        if (eCirc(circRad,Ma,a,l) < effPhi(circRad,Ma,a,l)): #no solutions
            return -1,-1
        #print('r_circ: ',circRad)
        minRad=rootBisection(1,circRad,effPhi,Ma,a,l,E)
        maxRad=rootBisection(circRad,1e5,effPhi,Ma,a,l,E)
        #print('r_apo: ',minRad,' and r_peri: ',maxRad)
    return minRad,maxRad

apos=np.zeros((nL,nE))
peris=np.zeros((nL,nE))
for i in range(nL):
    for j in range(nE):
        minRad,maxRad=findTurnRad(ls[i],Es[j])
        apos[i,j]=minRad
        peris[i,j]=maxRad

#print('apos: ',apos)
#print('peris: ',peris)

apoPlot=plotImage(apos,'r_apo',0,20)
periPlot=plotImage(peris,'r_peri',0,100)

grid=bokeh.layouts.gridplot([[apoPlot,periPlot]])
blt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd7a9453-e567-4890-976e-11012f339fd0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cd7a9453-e567-4890-976e-11012f339fd0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd7a9453-e567-4890-976e-11012f339fd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd7a9453-e567-4890-976e-11012f339fd0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fecb89e3-ed99-4f1c-82a1-e2bac0094b3b":{"roots":{"references":[{"attributes":{"plot":{"id":"1540d356-d38d-4b6c-b264-885c2a91fed4","subtype":"Figure","type":"Plot"}},"id":"f5f933f1-3a4f-40e6-a717-1f68767d2f3b","type":"SaveTool"},{"attributes":{"plot":{"id":"1540d356-d38d-4b6c-b264-885c2a91fed4","subtype":"Figure","type":"Plot"}},"id":"334faa15-29bc-490f-8e85-4d8122effd28","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[128,128]}]}},"id":"c8553bca-4ce6-401f-b0f9-447bafced0e9","type":"ColumnDataSource"},{"attributes":{"callback":null,"end
type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"13b1aab6-948a-442b-9756-48149049a99e","type":"BoxAnnotation"},"plot":{"id":"1540d356-d38d-4b6c-b264-885c2a91fed4","subtype":"Figure","type":"Plot"}},"id":"8bfe9d96-91de-4987-bcfe-d29cb66b48e3","type":"BoxZoomTool"},{"attributes":{},"id":"748e5684-1cbc-4ac7-8e79-4fc88df68754","type":"ToolEvents"},{"attributes":{"plot":{"id":"b63bce2e-f007-4cb6-bef7-4c4f3303944a","subtype":"Figure","type":"Plot"}},"id":"3d14ff12-fa91-4638-a432-4c18531eac6f","type":"ResetTool"},{"attributes":{},"id":"76ecb28e-0c1a-4404-bff6-86539eaef1fc","type":"ToolEvents"},{"attributes":{},"id":"d3d49851-7b3f-4d10-ab50-9f4ee7806fb6","type":"BasicTic ...

# %% [markdown]
# # 4.b

# %%
#l=1e3
#E=-5e4
#minRad,maxRad=findTurnRad(l,E)
#Tr=trapIntegrate(minRad,maxRad,50,timeIntegrand,Ma,a,l,E)
#print(Tr)
Trs=np.zeros((nL,nE))
dPsi=np.zeros((nL,nE))
for i in range(nL):
    for j in range(nE):
        minRad,maxRad=findTurnRad(ls[i],Es[j])
        if (maxRad==-1): #no circular orbit
            Trs[i,j]=0
            dPsi[i,j]=0
            continue
        Trs[i,j]=trapIntegrate(minRad,maxRad,50,timeIntegrand,Ma,a,ls[i],Es[j])
        dPsi[i,j]=trapIntegrate(minRad,maxRad,50,precessIntegrand,Ma,a,ls[i],Es[j]) % 2*np.pi

tPlot=plotImage(Trs,'period',0,1)
psiPlot=plotImage(dPsi,'precession',0,2*np.pi)

grid=bokeh.layouts.gridplot([[tPlot,psiPlot]])
blt.show(grid)
# Out:
# /Users/Zephyr/Astro/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# /Users/Zephyr/Astro/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in double_scalars
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f6c4dcb2-7f7f-43d1-880b-2418cd0452ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f6c4dcb2-7f7f-43d1-880b-2418cd0452ba").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6c4dcb2-7f7f-43d1-880b-2418cd0452ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6c4dcb2-7f7f-43d1-880b-2418cd0452ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fced7ac5-c380-4d67-905e-7b2ce2009bd4":{"roots":{"references":[{"attributes":{},"id":"1161b6ec-8adc-4673-851a-4c8d2a2e0b1d","type":"BasicTicker"},{"attributes":{"axis_label":"E","formatter":{"id":"9b34027c-fce9-4bc6-bf36-7d9452dcb255","type":"BasicTickFormatter"},"plot":{"id":"974f93f3-2736-450a-a366-a0a1fb02de17","subtype":"Figure","type":"Plot"},"ticker":{"id":"367dd798-0a12-4389-b284-c1a5e26a5d47","type":"BasicTicker"}},"id":"1ac1ede3-c8b0-4a44-bdf9-ac92e38937af","type":"LinearAxis"},{"attributes":{"axis_label":"E","formatter":{"id":"177be502-5a88-4aa9-b8dd-34b6ddab9ae6","type":"BasicTickFormatter"},"plot":{"id":"da520fc4-0870-457c-9f5f-792f315b6384","subtype":"Figure","type":"Plot"},"ticker":{"id":"2bc6c2b0-6499-4d2a-8c12-626e1ec8f299","type":"BasicTicker"}},"id":"18823a8e-abcc-43a6-b3e2-ecd4eb349428","type":"LinearAxis"},{"attributes":{},"id":"08da3cca-44ea-4375-b114-bdb858f95033","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":
type":"WheelZoomTool"},{"attributes":{"plot":{"id":"974f93f3-2736-450a-a366-a0a1fb02de17","subtype":"Figure","type":"Plot"},"ticker":{"id":"367dd798-0a12-4389-b284-c1a5e26a5d47","type":" ...

# %% [markdown]
# # q5

# %%
def dPhi_dR(rad,Ma,a):
    return G*rMass(rad,Ma,a)/rad**2
def dPhiEff_dR(rad,Ma,a,l):
    #print('dphi_dr: ',dPhi_dR(rad,Ma,a))
    #print('l2/r3: ',l**2/rad**3)
    return dPhi_dR(rad,Ma,a)-l**2/rad**3
class particleClass():
    def __init__(self):
        self.r=0
        self.rDot=0
        self.psiDot=0
    def leapFrog(self,dt):
        self.r+=self.rDot*dt
        #print('dt: ',dt)
        #print('r: ',self.r)
        rDotDot=-dPhiEff_dR(self.r,Ma,a,self.r**2 * self.psiDot)
        psiDotDot=-2*self.rDot*self.psiDot/self.r
        #print('rDotDot: ',rDotDot)
        #print('psiDotDot: ',psiDotDot)
        self.rDot+=rDotDot*dt
        self.psiDot+=psiDotDot*dt
        
endTime=1
nSteps=10000
dt=endTime/nSteps
p=particleClass()
E=-8.5e4
l=1e3
rApo,rPeri=findTurnRad(l,E)
print('expected apo and peri: ',rApo,' and ',rPeri)
p.r=rPeri
p.psiDot=l/p.r**2
rHist=np.zeros(nSteps)
lHist=np.zeros(nSteps)
eHist=np.zeros(nSteps)
for step in range(nSteps):
    p.leapFrog(dt)
    rHist[step]=p.r
    lHist[step]=(p.r**2) * p.psiDot
    eHist[step]=0.5*((p.rDot**2) *((p.r*p.psiDot)**2)) + phi(p.r,Ma,a)
    
rPlot=blt.figure(width=plotW,height=plotH,
                     y_axis_label='r',x_axis_label='t',
                     y_range=(0.9*rApo,1.1*rPeri),x_range=(0,endTime))
rPlot.line(dt*np.arange(0,nSteps),rHist,line_width=2)
rPlot.line([0,endTime],[rApo,rApo])
rPlot.line([0,endTime],[rPeri,rPeri])

consPlot=blt.figure(width=plotW,height=plotH,
                     y_axis_label='E and l drift',x_axis_label='t',
                     y_range=(0,2),x_range=(0,endTime))
consPlot.line(dt*np.arange(0,nSteps),lHist/l,line_width=2)
consPlot.line(dt*np.arange(0,nSteps),eHist/E,line_width=2,color='green')
consPlot.line([0,endTime],[1,1])

grid=bokeh.layouts.gridplot([[rPlot,consPlot]])
blt.show(grid)

print(eHist)
# Out:
# expected apo and peri:  3.13606009632349  and  7.580192938863547
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="52cc3c4e-3ea7-493e-bcb4-638967a17d00"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("52cc3c4e-3ea7-493e-bcb4-638967a17d00").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("52cc3c4e-3ea7-493e-bcb4-638967a17d00");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '52cc3c4e-3ea7-493e-bcb4-638967a17d00' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b03dd727-0a62-4a74-a6ff-52dc46ec416b":{"roots":{"references":[{"attributes":{"data_source":{"id":"1fc37c6e-c2e2-4689-864f-e2ba5ab1a1bf","type":"ColumnDataSource"},"glyph":{"id":"28d89ab6-3def-4d61-90e8-3a1ea96c81a5","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"