# %%
import numpy as np
import astropy.constants as const
import astropy.units as units
import bokeh.plotting as blt
import bokeh
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ad7cc05a-0a4e-4744-bc1b-bc6a4ccc2bd9">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # q3

# %%
#units are solar masses, kpc and Gyr
G=const.G.to((units.kpc**3)/(const.M_sun*(units.Gyr**2))).value
def vCirc(rad,Ma,a):
    return np.sqrt(G*rMass(rad,Ma,a)/rad)
def rMass(rad,Ma,a): #mass within radius r
    return Ma*( np.log(1+(rad/a)) - (rad/(a+rad)) )
def phi(rad,Ma,a):
    return -G*Ma*np.log(1+(rad/a))/rad
def effPhi(rad,Ma,a,l):
    return phi(rad,Ma,a) + ((l**2)/(2*(rad**2)))
def energy(rad,rDot,Ma,a,l):
    return (rDot**2)/2 + effPhi(rad,Ma,a,l)
def eCirc(rad,Ma,a,l): #energy assuming a circular orbit
    return (vCirc(rad,Ma,a)**2)/2 + phi(rad,Ma,a)
def lMax(rad,Ma,a,E):
    return rad*np.sqrt(2*(E-phi(rad,Ma,a)))

# %% [markdown]
# # 3.a

# %%
Ma=1e11
a=2
testR=np.linspace(0.1,25,100)
plotW=400
plotH=200
vCircPlot=blt.figure(width=plotW,height=plotH,
                     x_axis_label='r (kpc)',y_axis_label='v_c (kpc/Gyr)',
                     y_axis_type="log")
vCircPlot.line(testR,vCirc(testR,Ma,a),line_width=2)
mPlot=blt.figure(width=plotW,height=plotH,
                 x_axis_label='r (kpc)',y_axis_label='M_r (Msun)',
                 y_axis_type="log")
mPlot.line(testR,rMass(testR,Ma,a),line_width=2)
grid=bokeh.layouts.gridplot([[vCircPlot,mPlot]])
blt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a4676a8c-105f-4160-b405-701754b16036"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a4676a8c-105f-4160-b405-701754b16036").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4676a8c-105f-4160-b405-701754b16036");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4676a8c-105f-4160-b405-701754b16036' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"31cefaaf-b560-45b0-a813-e142f3f3c808":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f757235-f592-4c20-a6ee-cd2964eee88f","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"23cd424c-c5c7-4107-907c-16d79e63a520","type":"Line"},{"attributes":{"children":[{"id":"6b9a4c41-b478-449f-9282-60caf4e66f32","subtype":"Figure","type":"Plot"},{"id":"fcb288ab-23b7-45b4-a3ac-7ec514893b55","subtype":"Figure","type":"Plot"}]},"id":"0051a0ca-886d-4492-90ef-32c8041d66d5","type":"Row"},{"attributes":{"num_minor_ticks":10},"id":"033bb241-14be-42df-acf7-374a86f1bc7c","type":"LogTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"593a9173-0b27-452b-ba4a-bc5cb7883909","type":"Line"},{"attributes":{},"id":"302bdc87-4e13-4c0e-9836-458362256b4b","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"9eff88a8-0bd4-4b4a-8d10-77103ac1845d","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"26a90d1c-1209-4448-af60-440fd8e36834","type":"BoxAnnotation"},"plot":{"id":"fcb288ab-23b7-45b4-a3ac-7ec514893b55","subtype":"Figure","type":"Plot"}},"id":"35b56c10-9560-4a3e-b768-cb483711c01a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"3af29812-b141-4e52-bc4c-92b1f4f86290","type":"LinearAxis"}],"left":[{"id":"855ee1fb-125d-4ec9-9df9-a3ed82b73440","type":"LogAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"3af29812-b141-4e52-bc4c-92b1f4f86290","type":"LinearAxis"},{"id":"ca66cda9-954e-4e96-a959-fe7367c1683b","type":"Grid"},{"id":"855ee1fb-125d-4ec9-9df9-a3ed82b73440","type":"LogAxis"},{"id":"fea167d9-f663-4b1a-b391-fe253ad3c1f6","type":"Grid"},{"id":"d7991d75-29b4-45e0-88e0-0fc5d9c3d127","type":"BoxAnnotation"},{"id":"e139229a-edb7-40f6-bff4-de9ec8e814d3","type":"GlyphRenderer"}],"title":{"id":"ff194350-5016-4bd8-8f15-3e2108fd28c2","type":"Title"},"tool_events":{"id":"2ca8e3b2-a021-443f-9716-29e3b243a286","type":"ToolEvents"},"toolbar":{"id":"9c8c18c7-a568-4588-9212-835fea6b4b12","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"3f40a253-4049-461f-8181-d4fb54ad2f8e","type":"DataRange1d"},"y_mapper_type":"log","y_range":{"id":"e2957534-03dc-44db-a6e6-b6d273599874","type":"DataRange1d"}},"id":"6b9a4c41-b478-449f-9282-60caf4e66f32","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ba379c3e-9d93-400c-8812-eebc17aaf75b","type":"PanTool"},{"id":"6c838f75-2161-44c5-8b26-7e1b4983fb22","type":"WheelZoomTool"},{"id":"5e0f8e5b-862f-4b5a-97bf-50aa108dd2b8","type":"BoxZoomTool"},{"id":"1fb1bce4-5eb9-4bbf-bac7-2316d6aa46f6","type":"SaveTool"},{"id":"c2e37640-2d69-454f-817e-9bdc9950fa9b","type":"ResetTool"},{"id":"0e5ba3de-d2c6-401d-ae2a-23136fa2933f","type":"HelpTool"}]},"id":"9c8c18c7-a568-4588-9212-835fea6b4b12","type":"Toolbar"},{"attributes":{"plot":{"id":"fcb288ab-23b7-45b4-a3ac-7ec514893b55","subtype":"Figure","type":"Plot"}},"id":"a3830892-94b1-4f14-981d-1b68e10f9866","type":"SaveTool"},{"attributes":{"callback":null},"id":"e2957534-03dc-44db-a6e6-b6d273599874","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"5b8833c5-9d79-4110-b662-6838020038e3","type":"Title"},{"attributes":{"plot":{"id":"6b9a4c41-b478-449f-9282-60caf4e66f32","subtype":"Figure","type":"Plot"}},"id":"c2e37640-2d69-454f-817e-9bdc9950fa9b","type":"ResetTool"},{"attributes":{"plot":{"id":"6b9a4c41-b478-449f-9282-60caf4e66f32","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b6bc948-fd31-417a-b3d9-2ccb33cce9db","type":"BasicTicker"}},"id":"ca66cda9-954e-4e96-a959-fe7367c1683b","type":"Grid"},{"attribut ...

# %% [markdown]
# # 3.b

# %%
l=1e3
effPhiPlot=blt.figure(width=plotW,height=2*plotH,
                 x_axis_label='r (kpc)',y_axis_label='energy',
                 y_range=(-1e5,1e5),x_range=(0,25))
effPhiPlot.line(testR,effPhi(testR,Ma,a,l),line_width=2,legend='effective potential')
effPhiPlot.line(testR,eCirc(testR,Ma,a,l),line_width=2,color='green',legend='energy of circular orbit')
#effPhiPlot.ray(x=[0], y=[0], length=0, angle=0, line_width=2)
#effPhiPlot.ray(x=[0], y=[energy(np.zeros_like(testR),testR,Ma,a,l)]
#               ,length=0, angle=np.pi/2, line_width=2)
blt.show(effPhiPlot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf1310ec-b3e2-44b6-92b5-22243cbf418c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bf1310ec-b3e2-44b6-92b5-22243cbf418c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf1310ec-b3e2-44b6-92b5-22243cbf418c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf1310ec-b3e2-44b6-92b5-22243cbf418c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {
},{"attributes":{"plot":{"id":"a728a7c5-56ea-415b-8ca9-6f4bd953b1a7","subtype":"Figure","type":"Plot"}},"id":"222fefcf-aaf9-4014-a517-956fe866090e","type":"PanTool"},{"attributes":{"plot":{"id":"a728a7c5-56ea-415b-8ca9-6f4bd953b1a7","subtype ...

# %% [markdown]
# # q4

# %%
def timeIntegrand(rad,Ma,a,l,E):
    return 2/(2*(E-phi(rad,Ma,a)) + l**2/rad**2)**0.5
def precessIntegrand(rad,Ma,a,l,E):
    return 2*l/(rad**2 * (2*(E-phi(rad,Ma,a)) + l**2/rad**2)**0.5)
def rootBisection(lowBound,highBound,function,Ma,a,l,E):
    low=lowBound
    mid=0.5*(lowBound+highBound)
    high=highBound
    diff=1e10 #just a large number to get started
    count=0
    while((count<100) & (np.abs(diff/E)>0.001)):
        #print('count: ',count,' diff/E: ',diff/E)
        #print('low: ',low,' high: ',high)
        count+=1
        lowDiff=function(low,Ma,a,l)-E
        highDiff=function(high,Ma,a,l)-E
        diff=function(mid,Ma,a,l)-E
        if (np.sign(lowDiff*diff) == 1): #low and mid point on same side of root
            low=mid
            mid=0.5*(low+high)
        elif (np.sign(highDiff*diff) == 1): # high and mid point on same side of root
            high=mid
            mid=0.5*(low+high)
        #else:
            #print('something went wrong, 0 or 2+ roots in range')
    if (count==100):
        #print('did not converge')
        return -1
    return mid
def trapIntegrate(lowBound,highBound,nStep,function,Ma,a,l,E):
    integral=0
    step=np.linspace(lowBound,highBound,nStep+1)
    dStep=step[1]-step[0]
    for i in range(nStep):
        integral+=dStep*(function(step[i],Ma,a,l,E)+function(step[i+1],Ma,a,l,E))/2
    return integral
def plotImage(imageData,cbarName,cbarLow,cbarHigh):
    cmap = bokeh.models.LinearColorMapper(palette="PuOr11", low=cbarLow, high=cbarHigh)
    cbar = bokeh.models.ColorBar(color_mapper=cmap, border_line_color=None, location=(0,0),title=cbarName)
    plot=blt.figure(width=plotW,height=plotH,
                     y_axis_label='l',x_axis_label='E',
                     y_range=(ls[0],ls[-1]),x_range=(Es[0],Es[-1]))
    plot.add_layout(cbar, 'right')
    plot.image(image=[imageData],y=ls[0],x=Es[0],dh=ls[-1]-ls[0],dw=Es[-1]-Es[0],color_mapper=cmap)
    return plot
nL=128
nE=128
ls=np.linspace(5e2,5e3,nL)
Es=np.linspace(-1e5,1e5,nE)

# %% [markdown]
# # 4.a

# %%
def findTurnRad(l,E):
    minRad=-1
    maxRad=-1
    if(E>0): #only one root
        minRad=rootBisection(1,1e5,effPhi,Ma,a,l,E)
    elif(E<0):
        circRad=rootBisection(1,1e5,eCirc,Ma,a,l,E) #if 2 roots need to find center point to bisect around
        if (eCirc(circRad,Ma,a,l) < effPhi(circRad,Ma,a,l)): #no solutions
            return -1,-1
        #print('r_circ: ',circRad)
        minRad=rootBisection(1,circRad,effPhi,Ma,a,l,E)
        maxRad=rootBisection(circRad,1e5,effPhi,Ma,a,l,E)
        #print('r_apo: ',minRad,' and r_peri: ',maxRad)
    return minRad,maxRad

apos=np.zeros((nL,nE))
peris=np.zeros((nL,nE))
for i in range(nL):
    for j in range(nE):
        minRad,maxRad=findTurnRad(ls[i],Es[j])
        apos[i,j]=minRad
        peris[i,j]=maxRad

#print('apos: ',apos)
#print('peris: ',peris)

apoPlot=plotImage(apos,'r_apo',0,20)
periPlot=plotImage(peris,'r_peri',0,100)

grid=bokeh.layouts.gridplot([[apoPlot,periPlot]])
blt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="12bfefea-9938-4556-b44c-744ed308ad16"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("12bfefea-9938-4556-b44c-744ed308ad16").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
4","subtype":"Figure","type":"Plot"},"ticker":{"id":"a3ed9bc0-3c6a-4b46-828b-33c80c8ddb3c","type":"BasicTicker"}},"id":"8bd0db65-5e46-4ed5-af19-027531fccd93","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[128,128]}]}},"id":"8bd6f1dc-9653-44ba-8bf7-a7c1275d9d5c","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"9f6a97cb-d95e-4c0f-874c-9358ce6ee6c2","type":"ToolbarBox"},{"id":"6fe425d4-196b-4c29-b3f6-f287733d2257","type":"Column"}]},"id":"16d031bf-6eb0-4472-ad0a-48dc16cafc3b","type":"Column"},{"attributes":{},"id":"17296dd2-d3de-4cc8-ad85-16c3349e8432","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen"," ...

# %% [markdown]
# # 4.b

# %%
#l=1e3
#E=-5e4
#minRad,maxRad=findTurnRad(l,E)
#Tr=trapIntegrate(minRad,maxRad,50,timeIntegrand,Ma,a,l,E)
#print(Tr)
Trs=np.zeros((nL,nE))
dPsi=np.zeros((nL,nE))
for i in range(nL):
    for j in range(nE):
        minRad,maxRad=findTurnRad(ls[i],Es[j])
        if (maxRad==-1): #no circular orbit
            Trs[i,j]=0
            dPsi[i,j]=0
            continue
        Trs[i,j]=trapIntegrate(minRad,maxRad,50,timeIntegrand,Ma,a,ls[i],Es[j])
        dPsi[i,j]=trapIntegrate(minRad,maxRad,50,precessIntegrand,Ma,a,ls[i],Es[j]) % 2*np.pi

tPlot=plotImage(Trs,'period (Gyr)',0,1)
psiPlot=plotImage(dPsi,'precession',0,2*np.pi)

grid=bokeh.layouts.gridplot([[tPlot,psiPlot]])
blt.show(grid)
# Out:
# /Users/Zephyr/Astro/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# /Users/Zephyr/Astro/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in double_scalars
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e8e5f5b-bd37-4a0f-937b-baab70c0f849"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6e8e5f5b-bd37-4a0f-937b-baab70c0f849").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e8e5f5b-bd37-4a0f-937b-baab70c0f849");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e8e5f5b-bd37-4a0f-937b-baab70c0f849' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af2f9ac0-d3ac-4e26-aa4d-043d92f634f0":{"roots":{"references":[{"attributes":{},"id":"3293c056-bac0-4033-9dbf-9ba88a334f5e","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"e35de17e-74e9-46a4-b1c5-b2182205a913","type":"BoxAnnotation"},"plot":{"id":"99473491-b791-4650-83b1-db441563641f","subtype":"Figure","type":"Plot"}},"id":"598ce28a-f59a-4976-ab53-008e3f7b0fb3","type":"BoxZoomTool"},{"attributes":{"color_mapper":{"id":"9a768166-2a75-4b9a-8dbf-dc7f7733c483","type":"LinearColorMapper"},"dh":{"units":"data","value":4500.0},"dw":{"units":"data","value":200000.0},"image":{"field":"image"},"x":{"value":-100000.0},"y":{"value":500.0}},"id":"7c15a84f-c542-44fd-8498-2a25b935ec36","type":"Image"},{"attributes":{"axis_label":"E","formatter":{"id":"e2ea610c-05d0-400b-b513-3aed43ccbb3f","type":"BasicTickFormatter"},"plot":{"id":"b61833b8-a9e8-4b30-afcf-5a97b728c683","subtype":"Figure","type":"Plot"},"ticker":{"id":"7dd65971-6ec3-4e11-a6a4-980ca8027f97","type":"BasicTicker"}},"id":"588cfd3f-2302-4d80-9390-5b2cd495af63","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"f9de53f6-e739-4c5c-8239-b53a260d2435","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"73223ac4-43ff-431b-86b5-663bb90557f4","type":"BoxAnnotation"},{"attributes":{},"id":"17cb0c55-dd13-44f3-8bd9-6a3d1b7f0b44","type":"BasicTicker"},{"attributes":{"plot":{"id":"99473491-b791-4650-83b1-db441563641f","subtype":"Figure","type":"Plot"},"ticker":{"id":"17cb0c55-dd13-44f3-8bd9-6a3d1b7f0b44","type":"BasicTicker"}},"id":"ad4cd99a-63c2-414b-af17-bee30396a54c","type":"Grid"},{"attributes":{"plot":{"id":"b61833b8-a9e8-4b30-afcf-5a97b728c683","subtype":"Figure","type":"Plot"}},"id":"ca0a45c2-1fd0-4365-adff-e0c8fe562ad9","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bba2dff5-a1fe-482e-9c2b-0096cf52c883","type":"PanTool"},{"id":"f6d4aa69-3086-49f1-aae7-dc80ca875e8a","type":"WheelZoomTool"},{"id":"598ce28a-f59a-4976-ab53-008e3f7b0fb3","type":"BoxZoomTool"},{"id":"a611eab6-65bb-46e0-9d43-d77b67b433f1","type":"SaveTool"},{"id":"1c5eb2b8-4506-44cb-856f-eb2b3033b624","type":"ResetTool"},{"id":"24d08a1d-a108-49e0-b284-5d4c992b1823","type":"HelpTool"}]},"id":"e6b7aabe-561b-415b-b90d-f20be82fda65","type":"Toolbar"},{"attributes":{"plot":{"id":"99473491-b791-4650-83b1-db441563641f","subtype":"Figure","type":"Plot"}},"id":"a611eab6-65bb-46e0-9d43-d77b67b433f1","type":"SaveTool"},{"attributes":{},"id":"20c08f36-26a3-4976-a279-1395194cad31","type":"ToolEvents"},{"attributes":{},"id":"ac17e7d8-8a60-4f72-94c3-30a7510ad25f","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"9a768166-2a75-4b9a-8dbf-dc7f7733c483","type":"LinearColorMapper"},"dh":{"units":"data","value":4500.0},"dw":{"units":"data","value":200000.0},"image":{"field":"image"},"x":{"value":-100000.0},"y":{"value":500.0}},"id":"a89b5d2a-ce4a-4259-8614-04482adbf362","type":"Image"},{"attributes":{"plot":null,"text":""},"id":"908cc9a4-2aef-4e78-8bd5-68b5099d6572","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"28fcd32a-ed39-48e7-a9de-4ca53a30c4b2","type":"PanTool"},{"id":"e9943971-7b02-4de8-ac68-9948fece6857","type":"WheelZoomTool"},{"id":"e962ef23-0d5e-49bf-8e40-780ac2659ca8","type":"BoxZoomTool"},{"id":"be2fc7de-f949-470e-976c-d82e091bcbd4","type":"SaveTool"},{"id":"caef34e3-ffdc-43e0-90f0-9488e9972ea5","type":"ResetTool"},{"id":"ca0a45c2-1fd0-4365-adff-e0c8fe562ad9","type":"HelpTool"}]},"id":"e190d044-6ad0-44b4-ae46-555c1eed636e","type":"Toolbar"},{"attributes":{"color_mapper":{"id":"c3bc8940-2529-4d63-bf27-a6cea7cc1621","type":"LinearColorMapper"},"formatte ...

# %% [markdown]
# # q5

# %%
def dPhi_dR(rad,Ma,a):
    return G*rMass(rad,Ma,a)/rad**2
def dPhiEff_dR(rad,Ma,a,l):
    #print('dphi_dr: ',dPhi_dR(rad,Ma,a))
    #print('l2/r3: ',l**2/rad**3)
    return dPhi_dR(rad,Ma,a)-l**2/rad**3
def dPhi_dx(x,Ma,a):
    r=np.linalg.norm(x)
    return G*rMass(r,Ma,a)*x/r**3
class particleClass():
    def __init__(self):
        self.x=np.zeros(3)
        self.v=np.zeros(3)
        self.a=np.zeros(3)
    def leapFrog(self,dt):
        self.x+=self.v*dt
        self.a=-dPhi_dx(self.x,Ma,a)
        self.v+=self.a*dt
        
endTime=50
nSteps=10000
dt=endTime/nSteps
p=particleClass()
E=-4e4
l=1e3
rApo,rPeri=findTurnRad(l,E)
period=trapIntegrate(rApo,rPeri,100,timeIntegrand,Ma,a,l,E)
print('expected apo and peri: ',rApo,' and ',rPeri)
print('expected period: ',period)
p.x[0]=rApo
p.v[1]=l/rApo

xHist=np.zeros((3,nSteps))
vHist=np.zeros((3,nSteps))
rHist=np.zeros(nSteps)
lHist=np.zeros(nSteps)
eHist=np.zeros(nSteps)

for step in range(nSteps):
    p.leapFrog(dt)
    xHist[:,step]=p.x
    vHist[:,step]=p.v
    r=np.linalg.norm(p.x)
    rHist[step]=r
    v=np.linalg.norm(p.v)
    lHist[step]=np.linalg.norm( np.cross(p.x,p.v) )
    eHist[step]=0.5*(v**2) + phi(r,Ma,a)
    
pathPlot=blt.figure(width=plotW,height=2*plotH,
                     y_axis_label='y',x_axis_label='x',
                     y_range=(-1.1*rPeri,1.1*rPeri),x_range=(-1.1*rPeri,1.1*rPeri))
pathPlot.line(xHist[0,:],xHist[1,:],line_width=1)

rPlot=blt.figure(width=plotW,height=2*plotH,
                     y_axis_label='r(t)',x_axis_label='t',
                     y_range=(rApo-np.sqrt(rApo*rPeri),rPeri+np.sqrt(rApo*rPeri)),x_range=(0,endTime))
rPlot.line(dt*np.arange(0,nSteps),rHist[:],line_width=2)
rPlot.line([0,endTime],[rApo,rApo])
rPlot.line([0,endTime],[rPeri,rPeri])

maxVar=np.max(np.hstack( (np.abs(1-lHist/l) , np.abs(1-eHist/E)) ) )
consPlot=blt.figure(width=plotW,height=plotH,
                     y_axis_label='E and l drift',x_axis_label='t',
                     y_range=(1-2*maxVar,1+2*maxVar),x_range=(0,endTime))
consPlot.line(dt*np.arange(0,nSteps),lHist/l,line_width=2)
consPlot.line(dt*np.arange(0,nSteps),eHist/E,line_width=2,color='green')
consPlot.line([0,endTime],[1,1])

grid=bokeh.layouts.gridplot([[pathPlot,rPlot],[consPlot]])
blt.show(grid)

print(eHist)
# Out:
# expected apo and peri:  2.095124715771817  and  31.25276172506051
# expected period:  0.348670745516
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0ec6b28a-9319-4cba-ab26-eeb180d9962c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0ec6b28a-9319-4cba-ab26-eeb180d9962c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ec6b28a-9319-4cba-ab26-eeb180d9962c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ec6b28a-9319-4cba-ab26-eeb180d9962c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5541038d-7c7e-4ac3-903f-455221d4eae8":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e4aa5e7-39fd-448e-bc6e-4b48a212ecb3","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0e204c0f-fead-43a2-82d0-5a0808e204ba","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ee405c06-b1f9-4317-a4ae-56efe81563e4","subtype":"Figure","type":"Plot"}},"id":"328e4df1-cc91-42dc-a030-8b1280225e91","type":"WheelZoomTool"},{"attributes":{},"id":"6b137903-ae0a-4583-b5fc-2fc1d6e85430","type":"BasicTicker"},{"attributes":{},"id":"f22f2038-dd68-47d9-9ad3-d86845f0fe2e","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"