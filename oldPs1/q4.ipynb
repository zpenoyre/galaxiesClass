# %%
import numpy as np
import astropy.constants as const
import astropy.units as units
import bokeh.plotting as blt
import bokeh
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e33be1ff-e64a-43da-a080-96b5d0e2a37b">Loading BokehJS ...</span>
#     </div>

# %%
#units are solar masses, kpc and Gyr
G=const.G.to((units.kpc**3)/(const.M_sun*(units.Gyr**2))).value
def vCirc(rad,Ma,a):
    return np.sqrt(G*rMass(rad,Ma,a)/rad)
def rMass(rad,Ma,a): #mass within radius r
    return Ma*( np.log(1+(rad/a)) - (rad/(a+rad)) )
def phi(rad,Ma,a):
    return -G*Ma*np.log(1+(rad/a))/rad
def effPhi(rad,Ma,a,l):
    return phi(rad,Ma,a) + ((l**2)/(2*(rad**2)))
def energy(rad,rDot,Ma,a,l):
    return (rDot**2)/2 + effPhi(rad,Ma,a,l)
def eCirc(rad,Ma,a,l): #energy assuming a circular orbit
    return (vCirc(rad,Ma,a)**2)/2 + phi(rad,Ma,a)
def lMax(rad,Ma,a,E):
    return rad*np.sqrt(2*(E-phi(rad,Ma,a)))

# %% [markdown]
# # 3.a

# %%
Ma=1e11
a=2
testR=np.linspace(0.1,25,100)
plotW=400
plotH=200
vCircPlot=blt.figure(width=plotW,height=plotH,
                     x_axis_label='r (kpc)',y_axis_label='v_c (kpc/Gyr)',
                     y_axis_type="log")
vCircPlot.line(testR,vCirc(testR,Ma,a),line_width=2)
mPlot=blt.figure(width=plotW,height=plotH,
                 x_axis_label='r (kpc)',y_axis_label='M_r (Msun)',
                 y_axis_type="log")
mPlot.line(testR,rMass(testR,Ma,a),line_width=2)
grid=bokeh.layouts.gridplot([[vCircPlot,mPlot]])
blt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="93246153-0916-4d49-9a5e-a2880c7f1c7f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("93246153-0916-4d49-9a5e-a2880c7f1c7f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("93246153-0916-4d49-9a5e-a2880c7f1c7f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '93246153-0916-4d49-9a5e-a2880c7f1c7f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ca69421-c405-4f7a-b352-7f806f65f95d":{"roots":{"references":[{"attributes":{"plot":{"id":"d3a5c79e-5d45-4b70-8a4d-5090ea027525","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c02c654-820e-417c-b117-2b3b07a622ad","type":"BasicTicker"}},"id":"93037a97-b44f-437e-8a7c-acbce5d35bb2","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"f2d15fd4-74ad-4672-8e59-6401abbdcf93","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"931b8143-0983-4e9a-8df8-d960ac430980","type":"DataRange1d"},{"attributes":{"num_minor_ticks":10},"id":"b452d328-77bb-4069-99f2-b9e428ecf6ba","type":"LogTicker"},{"attributes":{"children":[{"id":"4bc0e9ca-b770-4ee5-a40c-899f94d3517d","type":"Row"}]},"id":"2a1f020e-ec34-4861-a03c-7367b073a92f","type":"Column"},{"attributes":{"data_source":{"id":"f84c3152-4740-407b-b2b0-b56873bc3e7c","type":"ColumnDataSource"},"glyph":{"id":"5e031c25-352c-4f16-8c01-a12ec463c074","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dfd3964e-23b3-44ce-ba07-043f50af6636","type":"Line"},"selection_glyph":null},"id":"0c48aa89-27fd-4751-b7ce-6c5a73c6b063","type":"GlyphRenderer"},{"attributes":{"axis_label":"r (kpc)","formatter":{"id":"31e161bd-aece-4aff-97f1-6fa93599a705","type":"BasicTickFormatter"},"plot":{"id":"db4a4241-855d-42a8-9eb7-9d86e279dff6","subtype":"Figure","type":"Plot"},"ticker":{"id":"00aa8a67-dfa1-4795-94b8-4acdbc59e5a2","type":"BasicTicker"}},"id":"2efd17fc-3e12-4c57-a8be-cf3b325f8fba","type":"LinearAxis"},{"attributes":{"plot":{"id":"d3a5c79e-5d45-4b70-8a4d-5090ea027525","subtype":"Figure","type":"Plot"}},"id":"aa599d67-8ae0-4fea-9e73-3bad2a92105f","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7b011da1-14e5-461b-a323-dc65fe983b4b","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"f84c3152-4740-407b-b2b0-b56873bc3e7c","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"dfd3964e-23b3-44ce-ba07-043f50af6636","type":"Line"},{"attributes":{"num_minor_ticks":10},"id":"45d8ba7c-9083-48fe-8585-069610ee7fb9","type":"LogTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fad4b998-076d-469d-bf23-48e0d7383184","type":"PanTool"},{"id":"391839c9-03a8-4bbc-bb87-e5e95bd0d27b","type":"WheelZoomTool"},{"id":"3ea44d77-cdd2-475b-8af1-d2cee49911c5","type":"BoxZoomTool"},{"id":"6178de56-3164-4363-aa37-e47690b7c2e7","type":"SaveTool"},{"id":"433f42d8-6637-4a90-8c71-8f355d601082","type":"ResetTool"},{"id":"aa599d67-8ae0-4fea-9e73-3bad2a92105f","type":"HelpTool"}]},"id":"38d41f89-d718-42ea-ae16-5e5d739f022f","type":"Toolbar"},{"attributes":{"callback":null},"id":"7a7af694-a086-46ac-8d7f-ac69fb9866a6","type":"DataRange1d"},{"attributes":{},"id":"00aa8a67-dfa1-4795-94b8-4acdbc59e5a2","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"db4a4241-855d-42a8-9eb7-9d86e279dff6","subtype":"Figure","type":"Plot"},"ticker":{"id":"45d8ba7c-9083-48fe-8585-069610ee7fb9","type":"LogTicker"}},"id":"491a4c96-100a-464f-9e8e-08819709fabf","type":"Grid"},{"attributes":{"axis_label":"v_c (kpc/Gyr)","formatter":{"id":"c4101a96-18a9-4646-aa29-2bd86c39e719","type":"LogTickFormatter"},"plot":{"id":"db4a4241-855d-42a8-9eb7-9d86e279dff6","subtype":"Figure","type":"Plot"},"ticker":{"id":"45d8ba7c-9083-48fe-8585-069610ee7fb9","type":"LogTi ...

# %% [markdown]
# # 3.b

# %%
l=1e3
effPhiPlot=blt.figure(width=plotW,height=2*plotH,
                 x_axis_label='r (kpc)',y_axis_label='energy',
                 y_range=(-1e5,1e5),x_range=(0,25))
effPhiPlot.line(testR,effPhi(testR,Ma,a,l),line_width=2,legend='effective potential')
effPhiPlot.line(testR,eCirc(testR,Ma,a,l),line_width=2,color='green',legend='energy of circular orbit')
#effPhiPlot.ray(x=[0], y=[0], length=0, angle=0, line_width=2)
#effPhiPlot.ray(x=[0], y=[energy(np.zeros_like(testR),testR,Ma,a,l)]
#               ,length=0, angle=np.pi/2, line_width=2)
blt.show(effPhiPlot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e7c15666-2935-480e-a514-1a1f15581d36"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e7c15666-2935-480e-a514-1a1f15581d36").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e7c15666-2935-480e-a514-1a1f15581d36");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e7c15666-2935-480e-a514-1a1f15581d36' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e3411d13-2506-49e4-b7b8-c780f3db4118":{"roots":{"references":[{"attributes":{},"id":"01a6f79d-8413-42a4-a06f-ec7ed707c40c","type":"BasicTicker"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0cc8849-7dd8-4d23-ae5d-41274fc21c06","type":"Line"},{"attributes":{"plot":{"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"Plot"}},"id":"c3003c54-1401-4416-8e83-42cfef519de6","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"c8cb4c4d-f1da-4ee4-aa87-b9bfcc187755","type":"Title"},{"attributes":{},"id":"1aeaf6c9-d09f-4b93-bdc4-1fd6de4836ce","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8bdc4ece-f968-4e13-9ac1-60f1a9db3161","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aeaf6c9-d09f-4b93-bdc4-1fd6de4836ce","type":"BasicTicker"}},"id":"1814f42c-3af1-4304-adfb-0ba045eefc7d","type":"Grid"},{"attributes":{"data_source":{"id":"621e9216-84d2-4186-a1a0-7f8762da27fb","type":"ColumnDataSource"},"glyph":{"id":"54ab176f-1bfd-4688-b986-c718f9e8b3a0","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a95c0c78-f524-400c-bcf9-8c4b0c089c58","type":"Line"},"selection_glyph":null},"id":"0e0d5aee-036c-4a8a-a6ea-67e38dd4aa43","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"8bdc4ece-f968-4e13-9ac1-60f1a9db3161","type":"BoxAnnotation"},"plot":{"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"Plot"}},"id":"2a9d3cda-0661-4442-8847-5a2474e9a23a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"538290c1-0360-48a6-af3d-ed78c20660d8","type":"LinearAxis"}],"left":[{"id":"dd418cd8-e27b-48ce-b57d-2662a1d845ac","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"538290c1-0360-48a6-af3d-ed78c20660d8","type":"LinearAxis"},{"id":"1814f42c-3af1-4304-adfb-0ba045eefc7d","type":"Grid"},{"id":"dd418cd8-e27b-48ce-b57d-2662a1d845ac","type":"LinearAxis"},{"id":"559ec80a-1726-4621-9b25-a073f5f0cd66","type":"Grid"},{"id":"8bdc4ece-f968-4e13-9ac1-60f1a9db3161","type":"BoxAnnotation"},{"id":"3c930b35-f2b8-4776-87aa-5487005e76d5","type":"Legend"},{"id":"0e0d5aee-036c-4a8a-a6ea-67e38dd4aa43","type":"GlyphRenderer"},{"id":"3f4d9cc7-93db-4410-a6ae-761036ff8844","type":"GlyphRenderer"}],"title":{"id":"c8cb4c4d-f1da-4ee4-aa87-b9bfcc187755","type":"Title"},"tool_events":{"id":"2f7a2645-15d0-43c2-8f51-4c9172917864","type":"ToolEvents"},"toolbar":{"id":"29fa6df1-11da-44c6-9eef-e81fbc240c9c","type":"Toolbar"},"x_range":{"id":"c0fb0ba2-e7b6-41b0-8e35-355175dfb7a2","type":"Range1d"},"y_range":{"id":"57c7ed38-4339-4d82-8ffd-fdf64246141a","type":"Range1d"}},"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"3a01e934-8aab-4d38-a796-d912f1ad1e5e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"Plot"}},"id":"25108a86-ef23-4dd2-a45b-371dcb3793b9","type":"HelpTool"},{"attributes":{},"id":"e3e0f38e-dbef-4a1e-8b0a-de65125018fc","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"effective potential"},"renderers":[{"id":"0e0d5aee-036c-4a8a-a6ea-67e38dd4aa43","type":"GlyphRenderer"}]},"id":"9f12f2e9-ec85-4e55-8503-04bff0751f9d","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"621e9216-84d2-4186-a1a0-7f8762da27fb","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"4e033f99-c9e2-49a0-97c0-051f13a02cfd","subtype":"Figure","type":"P ...

# %% [markdown]
# # 3.c

# %%
E=5
lMaxPlot=blt.figure(width=plotW,height=2*plotH,
                 x_axis_label='r (kpc)',y_axis_label='l_max',
                 x_range=(0,25))
lMaxPlot.line(testR,lMax(testR,Ma,a,E),line_width=2)
blt.show(lMaxPlot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e2db98e3-7abf-4817-baa2-6289cf073924"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e2db98e3-7abf-4817-baa2-6289cf073924").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e2db98e3-7abf-4817-baa2-6289cf073924");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e2db98e3-7abf-4817-baa2-6289cf073924' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b40c5c9c-f825-4721-89b7-7642f8301c35":{"roots":{"references":[{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"}},"id":"257e152e-0683-41de-a2a7-5a39726bcbdc","type":"ResetTool"},{"attributes":{"callback":null},"id":"11f01407-041e-4fdd-927e-ada9ae9ce720","type":"DataRange1d"},{"attributes":{},"id":"2c201435-56ee-4ec7-9855-bcb949cf90cc","type":"BasicTicker"},{"attributes":{"axis_label":"r (kpc)","formatter":{"id":"27f03ec3-0e0f-47f9-bde1-8b234440ef20","type":"BasicTickFormatter"},"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c201435-56ee-4ec7-9855-bcb949cf90cc","type":"BasicTicker"}},"id":"86360eeb-b33d-473b-b2a6-083f287c0a95","type":"LinearAxis"},{"attributes":{"axis_label":"l_max","formatter":{"id":"5b910c34-990b-4563-975e-b9b1a71ad519","type":"BasicTickFormatter"},"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"9313f593-a0fd-4447-9e1d-cabfefe6be82","type":"BasicTicker"}},"id":"c92f08fb-616f-4d88-a21f-dfd19a1d96f4","type":"LinearAxis"},{"attributes":{"callback":null,"end":25},"id":"aadb6040-de2d-4009-8953-af9c5dd40a8c","type":"Range1d"},{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c201435-56ee-4ec7-9855-bcb949cf90cc","type":"BasicTicker"}},"id":"98a49f69-75ef-44ca-b702-25d907514e29","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"50030e7d-bea2-424b-9d89-adbc9050dbf3","type":"Line"},{"attributes":{},"id":"9313f593-a0fd-4447-9e1d-cabfefe6be82","type":"BasicTicker"},{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"}},"id":"f326b5d7-e59e-4fe8-87d4-416fab1ce1e4","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"bef1c7bb-6c0e-44f3-99e5-8a34f44d566c","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"9313f593-a0fd-4447-9e1d-cabfefe6be82","type":"BasicTicker"}},"id":"28af987b-25ca-4a42-83b7-079938fe1d17","type":"Grid"},{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"}},"id":"0110c7bf-4383-4d51-8763-cc39672c1826","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"5a8e2304-8992-4159-bf27-65953ffd4bb9","type":"ColumnDataSource"},"glyph":{"id":"63109c8a-20f6-4191-a5e6-044d38a3d49a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"50030e7d-bea2-424b-9d89-adbc9050dbf3","type":"Line"},"selection_glyph":null},"id":"1b60ead8-a558-4584-9dd3-1a196da369ad","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"}},"id":"7c957a44-407d-4781-9c7d-241550d0f583","type":"SaveTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"63109c8a-20f6-4191-a5e6-044d38a3d49a","type":"Line"},{"attributes":{"plot":{"id":"c7c37398-fa2a-469a-b001-ad40aeb9d4ff","subtype":"Figure","type":"Plot"}},"id":"adfe78f7-17cf-455c-b5e8-ee5fefe4c27d","type":"HelpTool"},{"attributes":{},"id":"5b910c34-990b-4563-975e-b9b1a71ad519","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"86360eeb-b33d-473b-b2a6-083f287c0a95","type":"LinearAxis"}],"left":[{"id":"c92f08fb-616f-4d88-a21f-dfd19a1d96f4","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"86360eeb-b33d-473b-b2a6-083f287c0a95","type":"LinearAxis"},{"id":"98a49f69-75ef-44ca-b702-25d907514e29","type":"Grid"},{"id":"c92f08fb-616f-4d88-a21f-dfd19a1d96f4","type":"LinearAxis"},{"id":"28af987b-25ca-4a42-83b7-079938fe1d17","type":"Grid"},{"id":"149ad632-5066-48b2-b1aa-2cdc672a8c46","type":"BoxAnnotation"},{"id":"1b60ead8-a558-4584-9dd3-1a196da369ad","type":"GlyphRenderer"}],"t ...
